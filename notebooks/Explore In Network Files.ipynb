# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

# %%
in_network_files = pd.read_parquet('../data/in_network_files.parquet')

# %%
in_network_files = in_network_files.sort_values('location')

# %%
in_network_files
# Out:
#                                                          description  \
# 14                                 In-Network Negotiated Rates Files
# 17                                 In-Network Negotiated Rates Files
# 248                                In-Network Negotiated Rates Files
# 168                                In-Network Negotiated Rates Files
# 215                                In-Network Negotiated Rates Files
# ..                                                               ...
# 173                                 BCBS Tennessee, Inc. : Network P
# 197                                Regence BlueShield : BlueCard PPO
# 42                        Florida Blue: Triple-S (PR) : BlueCard PPO
# 135                          Florida Blue: Triple-S (VI) : USVI-62A0
# 132  Horizon BCBS New Jersey, Inc. : Select Hospitals/PAR Physicians
#
# ...

# %%
in_network_files.description.unique()
# Out:
# array(['In-Network Negotiated Rates Files',
#        'Arkansas BCBS : True Blue PPO', 'BCBS Arizona : Blue Preferred',
#        'BS California : PPO Network',
#        'Highmark BCBS Delaware : Blue Choice',
#        'BC Idaho : Preferred Blue',
#        'HCSC: BCBS Illinois : Participating Provider Option',
#        'Wellmark BCBS Iowa : ALLIANCE Select',
#        'BCBS Kansas : Blue Choice', 'BCBS Louisiana : Preferred Care',
#        'BCBS Mississippi : Par Network',
#        'BCBS Kansas City : Preferred Care PPO',
#        'HCSC: BCBS Montana : PPO Network', 'BCBS Nebraska : NEtwork BLUE',
#        'HCSC: BCBS New Mexico : New Mexico BlueCard PPO',
#        'Highmark BCBS Western NY : HighMark BlueCross BlueShield of Western New York-PPO',
#        'Excellus BCBS : BluePPO',
#        'BCBS North Carolina : Preferred Provider Network (PPN)',
#        'BCBS North Dakota : Preferred Blue PPO',
#        'HCSC: BCBS Oklahoma : BlueChoice PPO',
# ...

# %%
in_network_files.location.unique()
# Out:
# array(['https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/CA_ELHOMEDELHO.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/CA_ELRKMEDELRK.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/CA_ENKHMEDENKH.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/NY_GGHAMEDAP33_01_09.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/NY_GGHAMEDAP33_02_09.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/NY_GGHAMEDAP33_03_09.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/NY_GGHAMEDAP33_04_09.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/NY_GGHAMEDAP33_05_09.json.gz',
#        'https://antm-pt-prod-dataz-nogbd-nophi-us-east1.s3.amazonaws.com/anthem/NY_GGHAMEDAP33_06_09.json.gz',
# ...
